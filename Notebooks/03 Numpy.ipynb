# %%
import numpy
from matplotlib import pyplot as plt


plt.style.use("fivethirtyeight")

data = numpy.loadtxt("datos_graficas.txt")

plt.plot (data[0],data[1])
plt.plot (data[0],data[2])
plt.plot (data[0],data[3])
plt.ylim (-2,5)
# Out:
# (-2.0, 5.0)
